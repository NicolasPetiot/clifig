# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pickle

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 2], "ko")
pickle.dump((fig, ax), file=open(
    "fig_ax.pkl", "wb"
))

# %%
fig, ax = pickle.load(file = open(
    "fig_ax.pkl", "rb"
))

# %%
# Out:
# <module 'matplotlib.axis' from '/home/nico/miniconda3/lib/python3.11/site-packages/matplotlib/axis.py'>
